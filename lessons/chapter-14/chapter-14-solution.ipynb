# %%
# !pip install -q ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
clearscreen()

# %%
# solution for task
goto(0, 0)
goto(100, 0)
goto(50, 80)
goto(0, 0)

# %%
# solution for challenge
clearscreen()

# square base
goto(0, 0)
goto(100, 0)
goto(100, 80)
goto(0, 80)
goto(0, 0)

# triangular roof
goto(0, 80)
goto(50, 130)
goto(100, 80)
