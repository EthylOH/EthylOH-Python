# %%
# !pip install -q ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
clearscreen()

# %% [markdown]
# The Task
#
# Use goto() to draw a triangle by moving the Turtle to three coordinate points: (0, 0), (100, 0), (50, 80), and back to (0, 0).
