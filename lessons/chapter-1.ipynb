# %% [markdown]
# # Chapter 1: Talking to the Terminal
#
# Welcome! This notebook is your digital workbench. Today we learn to command the terminal.
#
# > **How to run code:** Click the ▶️ button to the left of any code cell. Or hit **Run All** at the top to run everything at once.

# %%
print("Hello! I am ready to start my Python journey.")
