# %%
# solution for task
# This next line prints my name
print("name")

# %%
# solution for challenge
# this draws the top of the head
print(" --------- ")
# this draws the eyes
print("|  O   O  |")
# this draws the nose
print("|    >    |")
# this draws the mouth
print("|  \\___/  |")
# this draws the bottom of the head
print(" --------- ")
