# %%
# solution for task
food = input("What is your favorite food? ")
print("I like to eat " + food)

# %%
# solution for challenge
color = input("Pick a color: ")
animal = input("Pick an animal: ")
place = input("Pick a place: ")
print("The " + color + " " + animal + " went to " + place)
