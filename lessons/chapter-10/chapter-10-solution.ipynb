# %%
# !pip install -q ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
clearscreen()

# %%
# solution for task
forward(100)
right(90)
forward(100)
right(90)
forward(100)
right(90)
forward(100)
right(90)

# %%
# solution for challenge
#for a polygon with 'n' sides
#turning angle = 360/n
#then write forward() and right() pair 'n' times
