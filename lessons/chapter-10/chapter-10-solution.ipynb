# %%
# !pip install -q ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
clearscreen()

# %%
# solution for task
forward(100)
right(90)
forward(100)
right(90)
forward(100)
right(90)
forward(100)
right(90)

# %%
# solution for challenge
clearscreen()
forward(100)
left(120)
forward(100)
left(120)
forward(100)
left(120)
