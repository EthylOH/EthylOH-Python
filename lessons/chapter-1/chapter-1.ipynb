# %% [markdown]
# Chapter 1: The Silent Box
#
# Welcome to the start of your programming journey. Right now, your computer has unimaginable processing power, but it has a major problem: it is a silent brick.
#
# It isn't talking to you. Even if it could, you need to know how to control exactly what it says.

# %% [markdown]
# Step 1: The Trap
#
# Imagine you want your computer to greet you. You might try just typing your thoughts directly into the code. Run the code cell below by clicking the Play button. Watch what happens.

# %%
"Computer, please say hello to me!"

# %% [markdown]
# Did you see that? It just spit your text back out with an output marker, but it didn't actually speak to the terminal properly. It is just echoing data. We need to use the computer's actual mouth.
#
# Before we do that, run the cell below to see a secret Python easter egg. We are going to literally defy gravity to start this course.

# %%
import antigravity

# %% [markdown]
# Step 2: The Tool (print)
#
# To make the computer officially display text on the screen, we use a built-in Python tool called print().
#
# Think of it like sending a text message from the computer's brain out to your screen. You simply type print(), and wrap your words in quotation marks "" inside the parentheses so the computer knows it is reading a human sentence.

# %% [markdown]
# Step 3: The Guided Fix
#
# Your job is to fix the silent computer. Look at the code cell below. Replace the underscores ____ with your actual name, and run the cell to make the computer speak!

# %%
print("Hello, my name is ____ and I am officially programming.")

# %% [markdown]
# Step 4: The Boss Fight
#
# The ASCII Art Challenge.
#
# You now know how to print one line of text. But what happens if you stack multiple print() commands on top of each other?
#
# Your challenge: Use at least 4 different print() statements in the blank cell below to draw a face, a sword, or an animal using only text characters (ASCII art).
