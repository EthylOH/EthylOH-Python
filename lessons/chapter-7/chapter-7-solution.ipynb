# %%
# solution for task
meal_price = float(input("Cost of your meal: "))
tip = meal_price * 0.15
print(tip)

# %%
# solution for challenge
num1 = float(input("Pick a number: "))
num2 = float(input("Pick another number: "))

print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
