# %%
# solution for task
result = 22 / 7
print(round(result, 4))

# %%
# solution for challenge
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the number to divide it by: "))
places = int(input("How many decimal places do you want to keep? "))

answer = num1 / num2
print(round(answer, places))
