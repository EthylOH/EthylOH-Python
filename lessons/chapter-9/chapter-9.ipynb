# %% [markdown]
# ### 3. The Task
#
# Build a "Pizza Price Calculator." Ask the user how many pizzas they want to order, then ask for the price of one pizza. Calculate the total cost and print it.

# %%
# Task: Pizza Price Calculator
quantity = int(input("How many pizzas? "))
price = float(input("Price per pizza? "))
total = quantity * price
print(f"Your total is: ${total}")

# %% [markdown]
# ### 4. Challenge
#
# Build a "Tip Calculator." Ask the user for the total bill amount and the percentage they want to tip. Use float() for the bill, calculate the tip, and print the final total.

# %%
# Challenge: Tip Calculator
