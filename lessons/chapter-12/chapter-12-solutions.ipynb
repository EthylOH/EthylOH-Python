# %%
# !pip install -q ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
clearscreen()

# %%
# solution for task
fillcolor("orange")
begin_fill()
forward(100)
left(120)
forward(100)
left(120)
forward(100)
left(120)
end_fill()

# %%
# solution for challenge
clearscreen()
bgcolor("black")

# red square
fillcolor("red")
begin_fill()
forward(80)
right(90)
forward(80)
right(90)
forward(80)
right(90)
forward(80)
right(90)
end_fill()

# move to the right
penup()
forward(120)
pendown()

# green triangle
fillcolor("green")
begin_fill()
forward(80)
left(120)
forward(80)
left(120)
forward(80)
left(120)
end_fill()
